# %%
import pandas as pd

# %%
df = pd.read_csv('./dataset/train.csv')

# %% [markdown]
# # Change types

# %%
df.dtypes
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age             object
# Delivery_person_Ratings         object
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weatherconditions               object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries             object
# Festival                        object
# City                            object
# Time_taken(min)                 object
# dtype: object

# %%
df['Delivery_person_Age'] = df['Delivery_person_Age'].astype( int )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1360/447483815.py in <module>
# ----> 1 df['Delivery_person_Age'] = df['Delivery_person_Age'].astype( int )
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1172         # work around NumPy brokenness, #1987
#    1173         if np.issubdtype(dtype.type, np.integer):
# -> 1174             return lib.astype_intsafe(arr, dtype)
#    1175
#    1176         # if we have a datetime/timedelta array of objects
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: 'NaN '

# %%
linhas_vazias = df[df['Delivery_person_Age'] != 'NaN ']
linhas_vazias
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x4607     INDORES13DEL02                   37                     4.9
# 1      0xb379     BANGRES18DEL02                   34                     4.5
# 2      0x5d6d     BANGRES19DEL01                   23                     4.4
# 3      0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4      0x70a2     CHENRES12DEL01                   32                     4.6
# ...        ...                ...                 ...                     ...
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                22.745049             75.892471                   22.765049
# 1                12.913041             77.683237                   13.043041
# 2                12.914264             77.678400                   12.924264
# 3                11.003669             76.976494                   11.053669
# 4                12.972793             80.249982                   13.012793
# ...                    ...                   ...                         ...
# 45588            26.902328             75.794257                   26.912328
# 45589             0.000000              0.000000                    0.070000
# 45590            13.022394             80.242439                   13.052394
# 45591            11.001753             76.986241                   11.041753
# 45592            23.351058             85.325731                   23.431058
#
#        Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                        75.912471  19-03-2022    11:30:00          11:45:00
# 1                        77.813237  25-03-2022    19:45:00          19:50:00
# 2                        77.688400  19-03-2022    08:30:00          08:45:00
# 3                        77.026494  05-04-2022    18:00:00          18:10:00
# 4                        80.289982  26-03-2022    13:30:00          13:45:00
# ...                            ...         ...         ...               ...
# 45588                    75.804257  24-03-2022    11:35:00          11:45:00
# 45589                     0.070000  16-02-2022    19:55:00          20:10:00
# 45590                    80.272439  11-03-2022    23:50:00          00:05:00
# 45591                    77.026241  07-03-2022    13:35:00          13:40:00
# 45592                    85.405731  02-03-2022    17:10:00          17:15:00
#
#            Weatherconditions Road_traffic_density  Vehicle_condition  \
# 0           conditions Sunny                High                   2
# 1          conditions Stormy                 Jam                   2
# 2      conditions Sandstorms                 Low                   0
# 3           conditions Sunny              Medium                   0
# 4          conditions Cloudy                High                   1
# ...                      ...                  ...                ...
# 45588       conditions Windy                High                   1
# 45589       conditions Windy                 Jam                   0
# 45590      conditions Cloudy                 Low                   1
# 45591      conditions Cloudy                High                   0
# 45592         conditions Fog              Medium                   2
#
#       Type_of_order Type_of_vehicle multiple_deliveries Festival  \
# 0            Snack      motorcycle                    0      No
# 1            Snack         scooter                    1      No
# 2           Drinks      motorcycle                    1      No
# 3           Buffet      motorcycle                    1      No
# 4            Snack         scooter                    1      No
# ...             ...             ...                 ...      ...
# 45588         Meal      motorcycle                    0      No
# 45589       Buffet      motorcycle                    1      No
# 45590       Drinks         scooter                    0      No
# 45591        Snack      motorcycle                    1      No
# 45592        Snack         scooter                    1      No
#
#                  City Time_taken(min)
# 0              Urban         (min) 24
# 1      Metropolitian         (min) 33
# 2              Urban         (min) 26
# 3      Metropolitian         (min) 21
# 4      Metropolitian         (min) 30
# ...               ...             ...
# 45588  Metropolitian         (min) 32
# 45589  Metropolitian         (min) 36
# 45590  Metropolitian         (min) 16
# 45591  Metropolitian         (min) 26
# 45592  Metropolitian         (min) 36
#
# [43739 rows x 20 columns]

# %% [markdown]
# # Aula 26

# %%
1. Qual o valor da informação armazenada na linha 30 e na coluna 10?
2. Selecione as linhas 0 a 20 e as colunas 0 a 2
3. Seleciona as linhas 5 a 30 e a coluna “Delivery_person_Age”
4. Selecione as linhas 40 a 42 e as seguintes colunas: “Restaurant_latitude”,
“Restaurant_longitude”, "Delivery_location_latitude”,
“Delivery_location_longitude”
5. Qual a menor data de entrega da coluna “Order_Date” entre as linhas 0 a
50?
6. Qual a menor data de entrega da coluna “ Time_Orderd ” entre as linhas
0 a 50?
7. Quais os nomes únicos da coluna “City” entre as linhas 50 e 70?
8. Quais os nomes únicos da coluna “Weatherconditions” entre as linhas 0 e
10?
9. Quais os tipos de densidade de trânsito presente na coluna
“Road_traffic_density ” entre as linhas 0 a 20?
10. Qual o ID do entregador de comida mais velho entre as colunas 50 e 70?
11. Qual o ID do entregador de comida com a melhor avaliação de entrega
entre as colunas 50 e 70?
12. Quais os tipos de veículos utilizados pelos entregadores entre as linhas 0
a 30?
13. Quais os tipos de pedidos único que foram entregues entre as colunas
100 e 120?
# Out:
#   File "C:\Users\leona\AppData\Local\Temp/ipykernel_1360/2446516751.py", line 1
#     1. Qual o valor da informação armazenada na linha 30 e na coluna 10?
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 1. Qual o valor da informação armazenada na linha 30 e na coluna 10?

# %%
df.iloc[30,10]

# %% [markdown]
# ## 2. Selecione as linhas 0 a 20 e as colunas 0 a 2

# %%
df.iloc[ 0:21 , 0:2 ]

# %% [markdown]
# ## 3. Seleciona as linhas 5 a 30 e a coluna “Delivery_person_Age”

# %%
pd.DataFrame(df.loc[5:30, "Delivery_person_Age"])

# %% [markdown]
# ## 4. Selecione as linhas 40 a 42 e as seguintes colunas:
# ### “Restaurant_latitude”,
# ### "Restaurant_longitude”, "Delivery_location_latitude”,
# ### "Delivery_location_longitude”

# %%
df.loc[40:42, ["Restaurant_latitude", "Restaurant_longitude", "Delivery_location_latitude" , "Delivery_location_longitude"]]

# %% [markdown]
# ## 5. Qual a menor data de entrega da coluna “Order_Date” entre as linhas 0 a 50?

# %%
min(df['Order_Date'])

# %% [markdown]
# ## 6. Qual a menor data de entrega da coluna “ Time_Orderd ” entre as linhas 0 a 50?

# %%
min(df.loc[0:50,'Time_Orderd'])

# %% [markdown]
# ## 7. Quais os nomes únicos da coluna “City” entre as linhas 50 e 70?

# %%
df.loc[50:70, "City"].unique()

# %% [markdown]
# ## 8. Quais os nomes únicos da coluna “Weatherconditions” entre as linhas 0 e 10?

# %%
list(df.loc[0:10, 'Weatherconditions'].unique())

# %% [markdown]
# ## 9. Quais os tipos de densidade de trânsito presente na coluna “Road_traffic_density ” entre as linhas 0 a 20?

# %%
list(df.loc[0:20, 'Road_traffic_density'].unique())

# %% [markdown]
# ## 10. Qual o ID do entregador de comida mais velho entre as colunas 50 e 70?

# %%
df.loc[50:70, ['Delivery_person_ID', 'Delivery_person_Age']].max()

# %%
df.head()

# %% [markdown]
# ## 11. Qual o ID do entregador de comida com a melhor avaliação de entrega entre as colunas 50 e 70?

# %%
df.loc[50:70, ['Delivery_person_ID', 'Delivery_person_Ratings']].max()

# %%
aux = df.loc[50:70, ['Delivery_person_ID', 'Delivery_person_Ratings']]
aux.sort_values("Delivery_person_Ratings", ascending=False).iloc[0, 0]

# %% [markdown]
# ## 12. Quais os tipos de veículos utilizados pelos entregadores entre as linhas 0 a 30?

# %%
list(df.loc[0:30, 'Type_of_vehicle'].unique())

# %% [markdown]
# ## 13. Quais os tipos de pedidos único que foram entregues entre as colunas 100 e 120?

# %%
list(df.loc[100:120, 'Type_of_order'].unique())

# %% [markdown]
# # Aula 30

# %%
df.head(20)
# Out:
#          ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0   0x4607     INDORES13DEL02                   37                     4.9
# 1   0xb379     BANGRES18DEL02                   34                     4.5
# 2   0x5d6d     BANGRES19DEL01                   23                     4.4
# 3   0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4   0x70a2     CHENRES12DEL01                   32                     4.6
# 5   0x9bb4      HYDRES09DEL03                   22                     4.8
# 6   0x95b4   RANCHIRES15DEL01                   33                     4.7
# 7   0x9eb2      MYSRES15DEL02                   35                     4.6
# 8   0x1102      HYDRES05DEL02                   22                     4.8
# 9   0xcdcd      DEHRES17DEL01                   36                     4.2
# 10  0xd987      KOCRES16DEL01                   21                     4.7
# 11  0x2784     PUNERES13DEL03                   23                     4.7
# 12  0xc8b6     LUDHRES15DEL02                   34                     4.3
# 13  0xdb64      KNPRES14DEL02                   24                     4.7
# 14  0x3af3      MUMRES15DEL03                   29                     4.5
# 15  0x3aab      MYSRES01DEL01                   35                       4
# 16  0x689b     PUNERES20DEL01                   33                     4.2
# 17  0x6f67      HYDRES14DEL01                   34                     4.9
# 18  0xc9cf      KOLRES15DEL03                   21                     4.7
# 19  0x36b8     PUNERES19DEL02                   25                     4.1
#
#     Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0             22.745049             75.892471                   22.765049
# 1             12.913041             77.683237                   13.043041
# 2             12.914264             77.678400                   12.924264
# 3             11.003669             76.976494                   11.053669
# 4             12.972793             80.249982                   13.012793
# 5             17.431668             78.408321                   17.461668
# 6             23.369746             85.339820                   23.479746
# 7             12.352058             76.606650                   12.482058
# 8             17.433809             78.386744                   17.563809
# 9             30.327968             78.046106                   30.397968
# 10            10.003064             76.307589                   10.043064
# 11            18.562450             73.916619                   18.652450
# 12            30.899584             75.809346                   30.919584
# 13            26.463504             80.372929                   26.593504
# 14            19.176269             72.836721                   19.266269
# 15            12.311072             76.654878                   12.351072
# 16            18.592718             73.773572                   18.702718
# 17            17.426228             78.407495                   17.496228
# 18            22.552672             88.352885                   22.582672
# 19            18.563934             73.915367                   18.643935
#
#     Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                     75.912471  19-03-2022    11:30:00          11:45:00
# 1                     77.813237  25-03-2022    19:45:00          19:50:00
# 2                     77.688400  19-03-2022    08:30:00          08:45:00
# 3                     77.026494  05-04-2022    18:00:00          18:10:00
# 4                     80.289982  26-03-2022    13:30:00          13:45:00
# 5                     78.438321  11-03-2022    21:20:00          21:30:00
# 6                     85.449820  04-03-2022    19:15:00          19:30:00
# 7                     76.736650  14-03-2022    17:25:00          17:30:00
# 8                     78.516744  20-03-2022    20:55:00          21:05:00
# 9                     78.116106  12-02-2022    21:55:00          22:10:00
# 10                    76.347589  13-02-2022    14:55:00          15:05:00
# 11                    74.006619  04-03-2022    17:30:00          17:40:00
# 12                    75.829346  13-02-2022    09:20:00          09:30:00
# 13                    80.502929  14-02-2022    19:50:00          20:05:00
# 14                    72.926721  02-04-2022    20:25:00          20:35:00
# 15                    76.694878  01-03-2022    14:55:00          15:10:00
# 16                    73.883572  16-03-2022    20:30:00          20:40:00
# 17                    78.477495  20-03-2022    20:40:00          20:50:00
# 18                    88.382885  15-02-2022    21:15:00          21:30:00
# 19                    73.995367  16-03-2022    20:20:00          20:25:00
#
#         Weatherconditions Road_traffic_density  Vehicle_condition  \
# 0        conditions Sunny                High                   2
# 1       conditions Stormy                 Jam                   2
# 2   conditions Sandstorms                 Low                   0
# 3        conditions Sunny              Medium                   0
# 4       conditions Cloudy                High                   1
# 5       conditions Cloudy                 Jam                   0
# 6          conditions Fog                 Jam                   1
# 7       conditions Cloudy              Medium                   2
# 8       conditions Stormy                 Jam                   0
# 9          conditions Fog                 Jam                   2
# 10      conditions Stormy                High                   1
# 11  conditions Sandstorms              Medium                   1
# 12  conditions Sandstorms                 Low                   0
# 13         conditions Fog                 Jam                   1
# 14  conditions Sandstorms                 Jam                   2
# 15       conditions Windy                High                   1
# 16  conditions Sandstorms                 Jam                   2
# 17      conditions Cloudy                 Jam                   0
# 18       conditions Windy                 Jam                   0
# 19  conditions Sandstorms                 Jam                   0
#
#    Type_of_order    Type_of_vehicle multiple_deliveries Festival  \
# 0         Snack         motorcycle                    0      No
# 1         Snack            scooter                    1      No
# 2        Drinks         motorcycle                    1      No
# 3        Buffet         motorcycle                    1      No
# 4         Snack            scooter                    1      No
# 5        Buffet         motorcycle                    1      No
# 6          Meal            scooter                    1      No
# 7          Meal         motorcycle                    1      No
# 8        Buffet         motorcycle                    1      No
# 9         Snack         motorcycle                    3      No
# 10         Meal         motorcycle                    1      No
# 11       Drinks            scooter                    1      No
# 12       Buffet         motorcycle                    0      No
# 13        Snack            scooter                    1      No
# 14       Buffet   electric_scooter                    1      No
# 15         Meal            scooter                    1      No
# 16        Snack         motorcycle                    1      No
# 17        Snack         motorcycle                 NaN       No
# 18         Meal         motorcycle                    1      No
# 19        Snack         motorcycle                    2      No
#
#               City Time_taken(min)
# 0           Urban         (min) 24
# 1   Metropolitian         (min) 33
# 2           Urban         (min) 26
# 3   Metropolitian         (min) 21
# 4   Metropolitian         (min) 30
# 5           Urban         (min) 26
# 6   Metropolitian         (min) 40
# 7   Metropolitian         (min) 32
# 8   Metropolitian         (min) 34
# 9   Metropolitian         (min) 46
# 10  Metropolitian         (min) 23
# 11  Metropolitian         (min) 21
# 12  Metropolitian         (min) 20
# 13  Metropolitian         (min) 41
# 14  Metropolitian         (min) 20
# 15  Metropolitian         (min) 33
# 16  Metropolitian         (min) 40
# 17  Metropolitian         (min) 41
# 18          Urban         (min) 15
# 19  Metropolitian         (min) 36

# %% [markdown]
# ## 1. Qual o número total de entregadores cadastrados na base de dados?

# %%
df[['Delivery_person_ID']].count()
# Out:
# Delivery_person_ID    45593
# dtype: int64

# %% [markdown]
# ## 2. Qual o número total de entregadores únicos cadastrados na base de dados?

# %%
df[['Delivery_person_ID']].nunique()
# Out:
# Delivery_person_ID    1320
# dtype: int64

# %% [markdown]
# ## 3. Qual a idade do entregador mais velho? E do mais novo?

# %%
filtered.sort_values(by='Delivery_person_Age', ascending=False)
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 8089   0x13a0      JAPRES02DEL01                 NaN                     NaN
# 22192  0x115f    COIMBRES20DEL01                 NaN                     NaN
# 21937   0x6a8     BANGRES07DEL01                 NaN                     NaN
# 36857   0x8bf    COIMBRES19DEL01                 NaN                     NaN
# 36854   0x465     CHENRES06DEL02                 NaN                     NaN
# ...        ...                ...                 ...                     ...
# 26917   0x6e0     CHENRES06DEL03                   15                       1
# 10900  0x1b49      MUMRES14DEL02                   15                       1
# 23035   0x415      VADRES17DEL01                   15                       1
# 16462   0xe4c      MYSRES05DEL03                   15                       1
# 22291   0x3ed   RANCHIRES09DEL01                   15                       1
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 8089             26.914142             75.805704                   26.924142
# 22192            10.994136             76.963303                   11.004136
# 21937            12.978453             77.643685                   13.088453
# 36857            11.022298             76.998349                   11.132298
# 36854           -13.054347            -80.257221                   13.104347
# ...                    ...                   ...                         ...
# 26917            13.054347             80.257221                   13.114347
# 10900            19.181300             72.836191                   19.231300
# 23035             0.000000              0.000000                    0.070000
# 16462            12.323978             76.627961                   12.413978
# 22291           -23.351058            -85.325731                   23.421058
#
#        Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 8089                     75.815704  07-03-2022        NaN           08:50:00
# 22192                    76.973303  11-03-2022        NaN           08:30:00
# 21937                    77.753685  12-03-2022        NaN           22:50:00
# 36857                    77.108349  10-03-2022    17:35:00          17:50:00
# 36854                    80.307221  01-04-2022        NaN           17:50:00
# ...                            ...         ...         ...               ...
# 26917                    80.317221  01-03-2022        NaN           18:20:00
# 10900                    72.886191  30-03-2022        NaN           20:55:00
# 23035                     0.070000  29-03-2022        NaN           00:00:00
# 16462                    76.717961  27-03-2022        NaN           20:00:00
# 22291                    85.395731  27-03-2022        NaN           21:35:00
#
#       Weatherconditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 8089   conditions Sunny                 Low                   1       Drinks
# 22192  conditions Windy                 Low                   0        Snack
# 21937  conditions Windy                 Low                   1       Drinks
# 36857    conditions Fog              Medium                   1         Meal
# 36854    conditions NaN                 NaN                   3         Meal
# ...                 ...                  ...                ...           ...
# 26917    conditions NaN                 NaN                   3         Meal
# 10900    conditions NaN                 NaN                   3       Buffet
# 23035    conditions NaN                 NaN                   3        Snack
# 16462    conditions NaN                 NaN                   3         Meal
# 22291    conditions NaN                 NaN                   3       Buffet
#
#          Type_of_vehicle multiple_deliveries Festival            City  \
# 8089            scooter                    0      No   Metropolitian
# 22192        motorcycle                    1      No   Metropolitian
# 21937           scooter                    1      No   Metropolitian
# 36857        motorcycle                    0      No           Urban
# 36854  electric_scooter                    0      No   Metropolitian
# ...                  ...                 ...      ...             ...
# 26917  electric_scooter                    1      No           Urban
# 10900        motorcycle                    1      No   Metropolitian
# 23035           scooter                    0      No           Urban
# 16462  electric_scooter                    0      No           Urban
# 22291  electric_scooter                    2     Yes   Metropolitian
#
#       Time_taken(min)
# 8089         (min) 18
# 22192        (min) 23
# 21937        (min) 13
# 36857        (min) 30
# 36854        (min) 30
# ...               ...
# 26917        (min) 21
# 10900        (min) 39
# 23035        (min) 27
# 16462        (min) 24
# 22291        (min) 44
#
# [45593 rows x 20 columns]

# %%
filtered = df[~df['Delivery_person_Age'].isna()]

# %%
df.dtypes
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age             object
# Delivery_person_Ratings         object
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weatherconditions               object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries             object
# Festival                        object
# City                            object
# Time_taken(min)                 object
# dtype: object
